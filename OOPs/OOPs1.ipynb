# %% [markdown]
# OOPs Concept :-
#
#         -> Object Oriented Language system
#         -> Everything in python is object like list, tuple
#         -> By OOPs user can make thier own data types
#         -> it makes easy to create real world applications
#
#     Oops consists certain principles
#         a. Object
#         b. Class
#         c. Polymorphism
#         d. Encapsulation
#         e. Inheritance
#         f. Abstraction

# %% [markdown]
# 1. Class =>
#
#        class is a blueprint
#        all data types are class and their values are object
# ------------------------------------------------
#    there are two things in class
#
#        -> Data or Property -> car=> name, color, top_speed
#        -> Function or Behavior -> Calcualte_avg_speed()
#
#     types of classes=>
#         1. built-in class => list, int, string
#         2. user define class => which are define by user by classes

# %% [markdown]
# 2. Object =>
#
#             Object is an instance of the class
#             -> car -> BMW
#             -> Animal -> Kutta
#
# syntax = > objectname = classname

# %%
# object literal 
l = [1,2,3]

# %%
 # objectname = classname
l = list([1,2,3])

# %% [markdown]
# ATM Banking Application

# %%
# passcal case -> HelloWorld

# %%
# use pascal case for name of class
# 
class Atm:
    # Constructor :- special function inside the class 
        # it has a superpower it executes automatically
        # we don't need to call explict this function 
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()
        
    def menu(self):
        user_input = input("""
        Hey, How can I help you 
        1. Press 1 to create pin 
        2. Press 2 to change pin 
        3. Press 3 to check balance 
        4. Press 4 to withdraw
        5. Anything else to exit
    """)
        
        if user_input == '1':
            # create pin 
            self.create_pin()
        elif user_input== '2':
            # change pin
            self.change_pin()
        elif user_input== '3':
            # check balance 
            self.check_balance()
        elif user_input== '4':
            # withdraw 
            self.withdraw()
        else:
            exit()

    def create_pin(self):
        user_pin = input("Enter your pin : ") 
        self.pin = user_pin 

        user_balance = int(input("Enter balance : "))
        self.balance = user_balance

        print("Pin created successfully")
        self.menu()

    def change_pin(self):
        old_pin = input('Enter old pin : ')

        if old_pin == self.pin:
            # let him change the pin 
            new_pin = input("Enter new pin : ")
            self.pin = new_pin 
            print('Pin change succcessful')
            self.menu()
        else:
            print("Your old pin is incorrect")
            
    def check_balance(self):
        user_pin = input("Enter you pin : ")
        if user_pin == self.pin:
            print('Your balance is : ', self.balance)
        else :
            print('Chal chal chal')
        self.menu() 
        
    def withdraw(self): 
        user_pin = input('Enter the pin : ')
        if user_pin == self.pin:
            amount = int(input('Enter the amount : '))
            if amount <= self.balance:
                self.balance = self.balance-amount
                print('Withdraw successfully')
                print('Balance is : ', self.balance)
            else : 
                print('Chal chal chal')
        else :
            print('Chal chal chal')

# %%
# Object can access the things inside the class
obj = Atm()
# Out:
#         Hey, How can I help you
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#      4
# Enter the pin :  2
# Chal chal chal

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %% [markdown]
# Function VS Method
#
# if a function is implimented in class then that is mehtod
# if a functino is independently exists outside the classs then that is function

# %%
l = [1,2,3,4]
print(len(l)) # function
l.append(4)  # mehtod
# Out:
# 4

# %% [raw]
# Constructor

# %%
class temp:
    def __init__(self):
        print('Hello')
obj = temp()
# Out:
# Hello

# %%
# making a data type fraction
class Fraction:
    # parametrized constructor => it need paramters while creating an object
    def __init__(self, x, y):
        self.num = x
        self.den = y

    # 
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)

    def __add__(self,other):
        new_num = self.num*other.den + other.num*self.den 
        new_den = self.den*other.den 
        return '{}/{}'.format(new_num,new_den) 
        
    def __sub__(self,other):
        new_num = self.num*other.den - other.num*self.den 
        new_den = self.den*other.den 
        return '{}/{}'.format(new_num,new_den) 
             
    def __mul__(self,other):
        new_num = self.num*other.num
        new_den = self.den*other.den 
        return '{}/{}'.format(new_num,new_den) 
             
    def __truediv__(self,other):
        new_num = self.num*other.den
        new_den = self.den*other.den 
        return '{}/{}'.format(new_num,new_den) 

    def convert_to_decimal(self):
        return self.num/self.den

# %%
fr1 = Fraction(4,5)
fr2 = Fraction(3,6)

# %%
print(fr1)
# Out:
# 4/5

# %%
print(fr2)
# Out:
# 3/6

# %%
print(fr1+fr2)
# Out:
# 39/30

# %%
print(fr1-fr2)
# Out:
# 9/30

# %%
print(fr1*fr2)
# Out:
# 12/30

# %%
print(fr1/fr2)
# Out:
# 24/30

# %%
fr1.convert_to_decimal()
# Out:
# 0.8
